# %% [markdown]
# ## this file merges old bee file with new bee file to vet new data

# %%
import pandas as pd

# %%
# Store filepath in a variable note that bees_new is a copy of original csv BIP_bee is newly sourced data for Bee Informed 
bees_one = "/Users/kathysmacbookpro2019/Desktop/bees_new.csv"
bees_two = "/Users/kathysmacbookpro2019/Desktop/BIP_bee.csv"

# %%
# Read our Data file with the pandas library - this ran before abd produced the output below but somewhere along the way I corrupted or deleted one of the CSVs
bees_one_df = pd.read_csv(bees_one)
bees_two_df = pd.read_csv(bees_two)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b3b7e285b520> in <module>
#       1 # Read our Data file with the pandas library
# ----> 2 bees_one_df = pd.read_csv(bees_one)
#       3 bees_two_df = pd.read_csv(bees_two)
#
# NameError: name 'pd' is not defined

# %%
bees_one_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 8 columns):
# Unnamed: 0           170 non-null int64
# State                170 non-null object
# Colonies             170 non-null int64
# Lost Colonies        170 non-null int64
# Year                 170 non-null int64
# Lost Unknown         168 non-null float64
# BIP Colonies         170 non-null int64
# BIP Colonies Lost    170 non-null int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 10.7+ KB

# %%
bees_two_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 4 columns):
# State                193 non-null object
# BIP Colonies         193 non-null int64
# BIP Colonies Lost    193 non-null int64
# Year                 193 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 6.1+ KB

# %%
merge_table_df = pd.merge(bees_one_df, bees_two_df, on = ["State", "Year"])
merge_table_df
# Out:
#      Unnamed: 0          State  Colonies  Lost Colonies  Year  Lost Unknown  \
# 0             0        Alabama     31000           4670  2015        521.19
# 1             1        Alabama     30500           4440  2016        506.17
# 2             2        Alabama     28000           3930  2017        258.70
# 3             3        Alabama     29500           4000  2018        228.40
# 4             4        Arizona    111000          20900  2016       1409.70
# 5             5        Arizona    106000          19200  2017        409.00
# 6             6       Arkansas     72500          14800  2015        512.10
# 7             7       Arkansas    111000          12400  2016        502.20
# 8             8       Arkansas     89000          18900  2017        250.50
# 9             9       Arkansas     95500          17800  2018       1452.30
# 10           10     California   3960000         584000  2015      20343.00
# ...

# %%
#merge_table_df.to_csv("/Users/kathysmacbookpro2019/Desktop/bees_new.csv")
