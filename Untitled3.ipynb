# %%
import pandas as pd 
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
# from towardsdatascience.com and author is Adarsh Menon "Linear Regression in 6 lines of python"-- TDS will be shorthand
from sklearn.linear_model import LinearRegression

# %%
path="bees_new_2.csv"
bees_df= pd.read_csv(path)
bees_gb= bees_df.groupby(["State"])["Colonies"].mean()
bees_pl_df=pd.DataFrame(bees_gb)
bees_final=bees_pl_df.drop(["Hawaii","California"])
bees_final
# Out:
#                  Colonies
# State
# Alabama           1687.25
# Arizona            876.00
# Arkansas          1766.25
# Colorado          2717.50
# Connecticut        253.75
# Florida          28555.50
# Georgia          13958.50
# Idaho            55717.50
# Illinois           864.75
# Indiana          10415.50
# Iowa               983.50
# Kansas            4648.00
# Kentucky          1881.75
# Louisiana        10204.00
# Maine             6182.00
# Maryland          3708.75
# Massachusetts     4166.25
# Michigan         20869.75
# Minnesota        23189.00
# Mississippi      13073.00
# Missouri           710.25
# Montana          20628.50
# Nebraska          9990.75
# New Jersey        1271.50
# New Mexico         183.00
# New York         10564.50
# North Carolina    3107.50
# North Dakota    120016.75
# Ohio              1799.75
# Oklahoma          4051.75
# Oregon           44564.25
# Pennsylvania      5895.50
# South Carolina    4583.75
# South Dakota     45633.75
# Tennessee         1301.00
# Texas            86340.00
# Utah              1529.25
# Vermont           1282.75
# Virginia          3560.00
# Washington       51253.75
# West Virginia      770.50
# Wisconsin        20309.00
# Wyoming           2519.00

# %%
path_towers="cell_states.csv"
towers_df=pd.read_csv(path_towers)
towers_df_abc=towers_df.sort_values("NAME")
towers_final=towers_df_abc.reset_index()
towers_final_drop=towers_final.drop([6,7,26,27,37,3])

# %%
X = towers_final_drop.iloc[:, 3].values.reshape(-1, 1)  # values converts it into a numpy array
Y = bees_final.iloc[:, 0].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column

linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

# %%
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.xlabel("Total Cell Phone Towers")
plt.ylabel("Avg. Total Colonies(2016-18)")
plt.title("Total Cell Phone Towers vs Avg Total Bee Colonies by State")
plt.grid()
plt.show()
# California is dropped

# %%
stats.pearsonr(X, Y)
# Out:
# (array([-0.12792903]), array([0.41362316]))
